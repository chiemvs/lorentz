# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

# %%
variables = ['gh', 'tcw', 't2m', 'sm20', 'sm100', 'sst','tp']

for var in ['tp']: #variables:
    for forctype in ['hindcast','forecast']:
        aggpath = Path('/data/volume_2/subseasonal/ecmwf/aggregated/') / forctype / f'ecmwf-{forctype}-{var}-week3456.nc'
        arr = xr.open_dataarray(aggpath)
        print(aggpath)
        print('min', arr.min())
        print('max', arr.max())
        #arr[:,0,0,0].plot()
        #arr.close()
# Out:
# /data/volume_2/subseasonal/ecmwf/aggregated/hindcast/ecmwf-hindcast-tp-week3456.nc
# min <xarray.DataArray ()>
# array(0., dtype=float32)
# max <xarray.DataArray ()>
# array(1929.4062, dtype=float32)
# /data/volume_2/subseasonal/ecmwf/aggregated/forecast/ecmwf-forecast-tp-week3456.nc
# min <xarray.DataArray ()>
# array(0., dtype=float32)
# max <xarray.DataArray ()>
# array(1653.1875, dtype=float32)

# %%
target = xr.open_dataarray('/data/volume_2/observational/preprocessed/chirps_tp_2000-2020_4weekly_0.25deg_africa.nc')

# %%
target[500,:,:].plot()

# %%
mask = xr.open_dataarray('/data/volume_2/observational/era5_hoa_dry_mask_0.25deg.nc')

# %%
mask.plot()

# %%
target.latitude
# Out:
# <xarray.DataArray 'latitude' (latitude: 292)>
# array([-35.375, -35.125, -34.875, ...,  36.875,  37.125,  37.375])
# Coordinates:
#   * latitude  (latitude) float64 -35.38 -35.12 -34.88 ... 36.88 37.12 37.38

# %%
mask.latitude
# Out:
# <xarray.DataArray 'latitude' (latitude: 221)>
# array([-30.  , -29.75, -29.5 , ...,  24.5 ,  24.75,  25.  ], dtype=float32)
# Coordinates:
#   * latitude  (latitude) float32 -30.0 -29.75 -29.5 -29.25 ... 24.5 24.75 25.0
#     quantile  float64 0.85
# Attributes:
#     units:      degrees_north
#     long_name:  latitude

# %%
pd.Timestamp
